# %%
import re
from datetime import datetime
from numpy import std
import os
import json

# %%
data_dir = "data"

# %%
mv_data_dir = ["../dataset/phase2/data/mouse_movements/bots","../dataset/phase2/data/mouse_movements/humans"]

# %%
json_f = None
for dir in mv_data_dir:
    for file_name in os.listdir(dir):
        print(file_name)
        with open(os.path.join(dir,file_name),'r') as file:
            for line in file:
                print(line[:20])
                json_f = json.loads(line)
                
                break
            break
# Out:
# mouse_movements_advanced_bots.json
# {"_id":{"$oid":"5fbe
# mouse_movements_humans.json
# {"_id":{"$oid":"5f02

# %%
json_f.keys()
# Out:
# dict_keys(['_id', 'session_id', 'mousemove_client_height_width', 'mousemove_times', 'mousemove_total_behaviour', 'mousemove_visited_urls', 'unique_id'])

# %%
json_f["mousemove_client_height_width"][:100
]
# Out:
# '[(938,1920)][(938,1920)][(938,1920)][(938,1920)][(938,1920)][(938,1920)][(938,1920)][(938,1920)][(93'

# %%
json_f["mousemove_times"][:100]
# Out:
# '1593975071137,1593975071228,1593975071247,1593975071261,1593975071278,1593975071295,1593975071311,15'

# %%
json_f["mousemove_total_behaviour"][:100]
# Out:
# '[m(456,701)][m(451,700)][m(436,707)][m(414,718)][m(404,731)][m(403,748)][m(406,769)][m(415,797)][m(4'

# %%
json_f["unique_id"][:100]
# Out:
# '694842305985'
