# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
sessions = ["mv_data2/1g4h4vh4d2uv360aoo55b086hd",
"mv_data2/tl2je8q2l4malkodn4inhd4n5o","mv_data2/v9jf53j6tf8mfrvn2mnmut46g9",
"mv_data/0p0kaqfmftrtfg0u12rkshrdi9","mv_data/7f2bg9n48opuf4ligvtc1dsopr","mv_data/v7qok0dv5ekcaoefquadgka6me"
]
sessions2 = ["mv_data/v3hbnujku5f0bm2mmbjqrr9rg8",
"mv_data/pvkqfvdopap7c1e9hrdeakkq8u","mv_data2/b6hfnt250mbc1h2qub8slvg0j4","mv_data2/4bnqt73v1q2ofhu8uj797irb7a"
]

# %%
for ses in sessions2:
    data = np.load(f"../scripts/{ses}.npz")
    cnt = 0
    for key in data:
        print(data[key].shape)
        plt.imshow(data[key], cmap='gray')   # 'gray' colormap forces grayscale display
        plt.axis('off')                 # hide axis for clean view
        if cnt>3:
            break
        cnt+=1
    plt.show()
# Out:
# (480, 720)
# (480, 720)
# (480, 720)
# (480, 720)
# (480, 720)
# (480, 720)
# (480, 720)
# (480, 720)
# (480, 720)
# (480, 720)
# (480, 720)
# (480, 720)
# (480, 720)
# (480, 720)
# (480, 720)
# (480, 720)
# (480, 720)
# (480, 720)
# (480, 720)
# (480, 720)
