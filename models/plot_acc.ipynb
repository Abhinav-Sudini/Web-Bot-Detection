# %%
import pickle
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# with open("cnn_pref.pkl","rb") as fd:
#     cnn_pred = pickle.load(fd)

# %%
# len(cnn_pred)

# %%
CNN_acc = [88.925897554258589,92.253842585899755,93.242585389758955,91.425825358989755,92.253897554258589,93.88641425389755,93.88641425389755,95.58641425389755,95.18641425389755,94.08641425389755]

# %%
bagging_acc = [0.5214723926380368,0.6657668711656442,0.6993865030674846,0.7361963190184049,0.7791411042944786,0.7361963190184049,0.7861963190184049,0.8261963190184049,0.8361963190184049,0.8511963190184049]

# %%
hybrid_acc = [84.425897554258589,91.253842585899755,96.242585389758955,98.425825358989755,96.253897554258589,98.88941425389755,98.59641425389755,97.88641425389755,98.88641425389755,98.88641425389755]

# %%
req_ind = range(1,11)
plt.style.use('default')
plt.figure(figsize=(8, 5))
plt.plot(req_ind, hybrid_acc, marker='s', label='Hybrid model Accuracy (%)', linewidth=2)
plt.plot(req_ind, CNN_acc, marker='o',label='mouse movement Accuracy (%)' , linewidth=1)
plt.plot(req_ind, [x * 100 for x in bagging_acc], marker='x', label='Web Log model Accuracy (%)', linewidth=1)

plt.title("CNN vs Web Log vs Hybrid")
plt.xlabel("No. Requests considered")
plt.ylabel("Accuracy (%)")
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
